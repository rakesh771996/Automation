# %% [markdown]
# <a href="https://colab.research.google.com/github/rakesh771996/Automation/blob/master/inception_v3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.applications import inception_v3
# Out:
# Using TensorFlow backend.

# %%
# pre trained weights : create my model
model = inception_v3.InceptionV3(weights='imagenet')
# Out:
# ...
# 96116736/96112376 [==============================] - 7s 0us/step

# %%
model.layers[0].input
# Out:
# <tf.Tensor 'input_1:0' shape=(None, 299, 299, 3) dtype=float32>

# %%
from keras.preprocessing import image

# %%
img = image.load_img('cat-dog.jpg', target_size=(299, 299))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=299x299 at 0x7F6BAF866BA8>

# %%
img.size
# Out:
# (299, 299)

# %%
type(img)
# Out:
# PIL.Image.Image

# %%
img_np = image.img_to_array(img)

# %%
img_np.shape
# Out:
# (299, 299, 3)

# %%
type(img_np)
# Out:
# numpy.ndarray

# %%
import numpy as np

# %%
a = np.array([1,2])

# %%
a.shape
# Out:
# (2,)

# %%
b = np.expand_dims(a, axis=0)

# %%
b.shape
# Out:
# (1, 2)

# %%
b[0]
# Out:
# array([1, 2])

# %%
ae = np.expand_dims(img_np, axis=0)

# %%
ae.shape
# Out:
# (1, 299, 299, 3)

# %%
from keras.applications.inception_v3 import decode_predictions

# %%
from keras.applications.inception_v3 import preprocess_input

# %%
finalimg = preprocess_input(ae)

# %%
pred = model.predict(finalimg)

# %%
decode_predictions(pred, top=3)[0]
# Out:
# [('n02099712', 'Labrador_retriever', 0.5143936),
#  ('n02099601', 'golden_retriever', 0.2846783),
#  ('n04409515', 'tennis_ball', 0.0067181895)]
